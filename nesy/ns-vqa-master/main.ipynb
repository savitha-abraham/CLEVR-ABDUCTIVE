# %%
#! nvidia-smi

# %%
#!lspci | grep ' VGA ' | cut -d" " -f 1 | xargs -i lspci -v -s {}

# %%
#! nvcc --version

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/CLEVR-ABDUCTIVE/nesy/ns-vqa-master/reason/tools')

# %%
#%cd /content/drive/MyDrive/ColabNotebooks/clevr-abductive/nesy/ns-vqa-master/reason
#%run executors/precompute.py

# %%
#%cd /content/drive/MyDrive/ColabNotebooks/clevr-abductive/nesy/ns-vqa-master/reason
#%run tools/preprocess_questions.py \
#--input_questions_json=../data/raw/CLEVR_v1.0/questions/CLEVR_train_questions.json \
#--output_h5_file=../data/reason/clevr_h5_3000/clevr_train_questions.h5 \
#--output_vocab_json=../data/reason/clevr_h5_3000/clevr_vocab.json

# %%
#%cd /content/drive/MyDrive/ColabNotebooks/clevr-abductive/nesy/ns-vqa-master/reason
#%run tools/preprocess_questions.py \
#--input_questions_json=../data/raw/CLEVR_v1.0/questions/CLEVR_val_questions.json \
#--output_h5_file=../data/reason/clevr_h5_3000/clevr_val_questions.h5 \
#--input_vocab_json=../data/reason/clevr_h5_3000/clevr_vocab.json

# %%
#%cd /content/drive/MyDrive/ColabNotebooks/clevr-abductive/nesy/ns-vqa-master/reason
#%run tools/sample_questions.py --n_questions_per_family 20 --input_question_h5 ../data/reason/clevr_h5_3000/clevr_train_questions.h5 --output_dir ../data/reason/clevr_h5_3000

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/clevr-abductive/nesy/ns-vqa-master/reason
# %run tools/run_train.py --checkpoint_every 1000 --num_iters 5000 --run_dir ../data/reason/outputs_3000/model_pretrain_uniform_270pg_check --clevr_train_question_path ../data/reason/clevr_h5_3000/clevr_train_20questions_per_family.h5
# Out:
# /content/drive/MyDrive/ColabNotebooks/clevr-abductive/nesy/ns-vqa-master/reason
# cuda available..
# | options
# run_dir: ../data/reason/outputs_3000/model_pretrain_uniform_270pg_check
# dataset: clevr
# shuffle: 1
# num_workers: 8
# manual_seed: None
# gpu_ids: [0]
# visualize: 0
# clevr_train_scene_path: ../data/raw/CLEVR_v1.0/scenes/CLEVR_train_scenes.json
# clevr_complete_train_scene_path: ../data/raw/CLEVR_v1.0/scenes/complete_train_scenes.json
# clevr_complete_val_scene_path: ../data/raw/CLEVR_v1.0/scenes/complete_val_scenes.json
# clevr_constraint_scene_path: ../data/raw/CLEVR_v1.0/scenes/constraints.json
# clevr_val_scene_path: ../data/raw/CLEVR_v1.0/scenes/CLEVR_val_scenes.json
# clevr_train_question_path: ../data/reason/clevr_h5_3000/clevr_train_20questions_per_family.h5
# clevr_val_question_path: ../data/reason/clevr_h5_3000/clevr_val_questions.h5
# clevr_vocab_path: ../data/reason/clevr_h5_3000/clevr_vocab.json
# max_train_samples: None
# max_val_samples: 10000
# ...

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/clevr-abductive/nesy/ns-vqa-master/reason
# %run tools/run_train.py --reinforce 1 --learning_rate 1e-5 --checkpoint_every 1 --num_iters 20000 --run_dir ../data/reason/outputs_3000/model_reinforce_uniform_270pg --load_checkpoint_path ../data/reason/outputs_3000/model_pretrain_uniform_270pg/checkpoint_best.pt
